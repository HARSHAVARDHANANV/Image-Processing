# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("sample.jpg", 0)

plt.imshow(img, cmap='gray')
plt.title("Original Image")
plt.axis("off")
plt.show()

# %%
plt.hist(img.ravel(), 256, [0,256])

plt.title("Histogram")
plt.xlabel("Pixel Intensity")
plt.ylabel("Number of Pixels")

plt.show()
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_5132\1340651681.py:1: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(img.ravel(), 256, [0,256])

# %%
equalized = cv2.equalizeHist(img)

plt.imshow(equalized, cmap='gray')
plt.title("Histogram Equalization")
plt.axis("off")
plt.show()

# %%
plt.hist(equalized.ravel(), 256, [0,256])

plt.title("Equalized Histogram")
plt.xlabel("Pixel Intensity")
plt.ylabel("Number of Pixels")

plt.show()
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_5132\3445548733.py:1: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(equalized.ravel(), 256, [0,256])

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.imshow(img, cmap='gray')
plt.title("Original")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(equalized, cmap='gray')
plt.title("Equalized")
plt.axis("off")

plt.show()
